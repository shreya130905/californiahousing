# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## load the dataset

# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset= fetch_california_housing()

# %%
type(dataset)
#bunch is ntg just use keys function
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# ## understand the dataset

# %%
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
#lets check the description(DESCR) of the dataset
print(dataset.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(dataset.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(dataset.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(dataset.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %% [markdown]
# ## prepare the dataset

# %%
df= pd.DataFrame(dataset.data, columns= dataset.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['Price']= dataset.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.info() #analysis for the dataset, also check for missing values, categorical to numerical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#summarizing the stats of the data
df.describe() #does not work for categorical features
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
#check the missing values whenever you get the dataset v imp
df.isnull().sum() #if any value in the dataset is 'true' that means its null
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64

# %% [markdown]
# ## exploratory data analysis

# %%
# we are just going to analyse some info of the dataset
# correlation(firsct code you need to learn if linear regression problem) if independent features of the dataset are higly positively correlated or highly negatively correalted then 
# our model performance will be high

# %% [markdown]
# ## Analyzing the correlated features

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %% [raw]
# Q. What is Pearson Correlation? ( this is the default correlation used here)
#
# It measures the linear relationship between two variables
# Range: -1 to +1
# +1 → strong positive correlation
# -1 → strong negative correlation
# 0 → no correlation
#
# There are two types of correlations to check
#
# 1)Independent vs Independent → Multicollinearity
# If two input features are highly correlated (around |0.9| or more):
# They carry duplicate information
# We drop one of them
# This is important for linear regression because multicollinearity makes coefficients unstable
#
# Example:
# Tax & Indus = 0.72 → somewhat high but not enough to drop
# If it were 0.95 → we would remove one feature
#
# 2️)Independent vs Dependent (Target variable)
# This tells us which features influence the target (price)
# Examples:
# CRIM vs PRICE = -0.38
# Higher crime → lower house price (negative relationship)
# RM vs PRICE ≈ +0.69
# More rooms → higher house price (positive relationship)
#
# These features are important predictors for the model.
#
# Visualization methods
#
# ✔ Heatmap
# Shows the full correlation matrix in one view
#
# ✔ Scatter plot
# Shows the relationship between two variables
# Upward trend → positive correlation
# Downward trend → negative correlation
#
# ✔ Pairplot
# Shows scatter plots for all feature pairs
# (Becomes cluttered when there are many features)
#
# Q. Why correlation is important in ML
#
# Helps in feature selection
# Detects multicollinearity
# Identifies important variables
# Improves linear regression performance

# %%
#analyze wrt to independent and dependent feature
plt.scatter(df['MedInc'], df['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df['AveRooms'], df['Price'])
plt.xlabel("AveRooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [raw]
# if there is one independent feature and one dependent feature and if we create a regression plot
# then how it will look like ? for this we will use seaborn

# %%
import seaborn as sns
sns.regplot(x="MedInc", y= "Price",data=df)
# Out:
# <Axes: xlabel='MedInc', ylabel='Price'>

# %%
sns.regplot(x="HouseAge", y= "Price", data=df)
# Out:
# <Axes: xlabel='HouseAge', ylabel='Price'>

# %%
sns.regplot(x="AveOccup", y= "Price", data=df)
# Out:
# <Axes: xlabel='AveOccup', ylabel='Price'>

# %% [raw]
# Linearity should there be in your dataset, i.e when x is increasing y increases too and when x decreasing then y is increasing to create a better regression model. so usually whenever we have this kind of features that are hardly correlated right..it reduces the error of the regression model ...

# %% [raw]
# so now we can create our models and for creating our models there are multiple steps that we really need
# to perform:
# -we need to prepare our independent and dependent features and
# -we need to do train test split
# -and many more things
#
# Step 1: Dividing our features into independent and dependent features

# %%
## Independent and Dependent features 
X=df.iloc[:,:-1] #[:,:-1] means to take up all the independent features only and skip last column that is price
y=df.iloc[:,-1] #all my data points and last column price

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3, random_state=42)
#all the features that are going to create wrt the train test split
print(X_train.shape)
print(y_train.shape)
# Out:
# (14448, 8)
# (14448,)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# ...

# %%
y_train
# Out:
# 7061     1.93800
# 14689    1.69700
# 17323    2.59800
# 10056    1.36100
# 15750    5.00001
#           ...
# 11284    2.29200
# 11964    0.97800
# 5390     2.22100
# 860      2.83500
# 15795    3.25000
# Name: Price, Length: 14448, dtype: float64

# %% [raw]
# Standardizing the dataset
# Before training a Linear Regression model using Gradient Descent, we apply Standard Scaling to the features.
#
# In real datasets, features are measured in different units. For example, one feature may have values in thousands while another may have values between 1 and 10.
#
# Gradient Descent updates weights based on partial derivatives of the cost function. If one feature has much larger values, its gradient becomes larger and dominates the updates.
#
# Because of different scales, the cost function surface becomes stretched (elongated shape instead of circular). This causes Gradient Descent to move in a zig-zag path.
#
# Zig-zag movement means slower convergence to the global minimum. Training takes more iterations and becomes inefficient.
#
# Standard Scaling transforms each feature using the formula:
# (value − mean) / standard deviation
#
# After scaling, each feature has mean = 0 and standard deviation = 1. All features are now on the same scale.
#
# When features are on the same scale, the cost function becomes more symmetric. Gradient Descent moves smoothly and reaches the minimum faster.
#
# Standard Scaling does not directly increase model accuracy, but it improves convergence speed, stability, and overall training efficiency.
#
# Clean data → smoother optimization → faster learning. Simple but powerful step.

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train= scaler.fit_transform(X_train)

# %% [raw]
# After creating the StandardScaler object, we apply it to the training data using fit_transform(X_train).
#
# fit() calculates the mean and standard deviation from the training data.
#
# transform() scales the data using those calculated values.
#
# fit_transform() does both steps together and returns the scaled version of X_train.
#
# The result is a standardized training dataset where all features are on the same scale and ready for model training.

# %%
X_test= scaler.transform(X_test)

# %% [raw]
# For the test data (X_test), we do not use fit_transform().
#
# We only use transform(X_test).
#
# This is because the scaler has already learned the mean and standard deviation from the training data using fit().
#
# We must apply the same scaling parameters (from training data) to the test data.
#
# If we use fit() again on X_test, it would calculate new mean and standard deviation, which means we are leaking information from the test set.
#
# Avoiding fit() on test data prevents data leakage and ensures the model does not learn anything from the test set during training.
#
# So the correct process is:
#
# fit_transform() on X_train
#
# transform() only on X_test

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]], shape=(14448, 8))

# %%
X_test
# Out:
# array([[-1.1526893 , -0.28346293, -0.50781822, ...,  0.06127763,
#          0.19166399,  0.28664112],
#        [-0.70640568,  0.11294728, -0.16252032, ..., -0.03551561,
#         -0.23911452,  0.06196251],
#        [-0.20830675,  1.85715216, -0.59546738, ..., -0.14215427,
#          1.00639726, -1.42590916],
#        ...,
#        [-0.19155996, -0.99700129, -0.6830438 , ..., -0.06058827,
#         -0.92742367,  0.8358555 ],
#        [-0.11911302, -1.47269353,  0.02607207, ...,  0.03461374,
#          1.01576201, -0.84673764],
#        [-0.43304974, -0.91771925, -0.84872893, ..., -0.0407528 ,
#         -0.70266966,  0.67109119]], shape=(6192, 8))

# %% [raw]
# Question:
# Why do you standardize the dataset in Linear Regression?
#
# Answer:
# In Linear Regression, we often use Gradient Descent to minimize the cost function and reach the global minimum. If the independent features are on different scales, the cost function becomes stretched and Gradient Descent converges slowly. By standardizing the features so that they are on the same scale, convergence becomes faster and more stable.
#
# Another possible question:
# Why do we apply fit_transform on training data but only transform on test data?
#
# Answer:
# We use fit_transform on the training data because the scaler needs to learn the mean and standard deviation from it. For the test data, we only use transform so that we apply the same scaling parameters. This prevents data leakage and ensures the model does not learn information from the test set.

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train, y_train) #in order to train just this
#you will be able to see that regression model is created right now this in short once we do fit so on that entire data
#set we basically create a hyper plane because understand here i have so many features i cannot say that i'll just be creating a 3d planar lock like i'll be creating a hyper plane
#because i really have so many number of features that are existing over there okay so quickly if i really want to
# Out:
# LinearRegression()

# %%
#print the coefficients and the intercept(whenever we solve the regression prob these two are imp things)
print(regression.coef_)
# Out:
# [ 8.49221760e-01  1.22119309e-01 -2.99558449e-01  3.48409673e-01
#  -8.84488134e-04 -4.16980388e-02 -8.93855649e-01 -8.68616688e-01]

# %%
print(regression.intercept_)
# Out:
# 2.0692396089424165

# %%
regression.get_params() #on which parameters the model has been trained
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
## Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133], shape=(6192,))

# %% [markdown]
# ## Assumptions

# %%
#plot the scattered plot for the prediction
plt.scatter(y_test, reg_pred)

# %%
#residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 20046   -0.249049
# 3024    -1.309434
# 15663    2.289088
# 20484   -0.649147
# 9814     0.173042
#            ...
# 17505    0.155059
# 13512   -0.237516
# 10842    0.109345
# 16559   -0.379714
# 5786     0.270559
# Name: Price, Length: 6192, dtype: float64

# %%
##plot this residuals

sns.displot(residuals, kind="kde")

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(reg_pred, residuals)

# %%
#performance metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test, reg_pred))
print(mean_squared_error(y_test, reg_pred))
print(np.sqrt(mean_squared_error(y_test, reg_pred)))
# Out:
# 0.5272474538305952
# 0.5305677824766755
# 0.7284008391515454

# %% [markdown]
# ## R Square And Adjusted R Square (other performance metrics)

# %%
from sklearn .metrics import r2_score
score= r2_score(y_test, reg_pred)
print(score)
# Out:
# 0.5957702326061662

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.5952472117200025

# %% [markdown]
# ## New Data Prediction

# %%
dataset.data[0].reshape(1,-1)
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#          322.        ,    2.55555556,   37.88      , -122.23      ]])

# %%
regression.predict(scaler.transform(dataset.data[0].reshape(1,-1)))
# Out:
# C:\Users\Shreya\.conda\envs\ml_clean\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])

# %% [markdown]
# ## Pickling The Model File For Deployment

# %%
import pickle #file that will help us do the pickling of this regression model

# %%
pickle.dump(regression, open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl', 'rb'))

# %%
## Prediction
pickled_model.predict(scaler.transform(dataset.data[0].reshape(1,-1)))
# Out:
# C:\Users\Shreya\.conda\envs\ml_clean\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])
